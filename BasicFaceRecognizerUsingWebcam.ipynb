# %% [markdown]
# # Basic face recognizer using pre trained model
#
# Below the is the implementation of a very basic face recognizer which can identify the face of the person showing on a web cam.
# The implementation is inspired by two path breaking papers on facial recognition using deep convoluted neural network, namely FaceNet and DeepFace.
#
# I have used pre trained model Keras-OpenFace which is an open source Keras implementation of the OpenFace (Originally Torch implemented)
#
# The pretrained model that I have used is by Victor Sy Wang's implementation and was loaded using his code: https://github.com/iwantooxxoox/Keras-OpenFace.

# %% [markdown]
# # Import the prerequisite libraries
#
# We will be importing utils.py from https://github.com/iwantooxxoox/Keras-OpenFace/blob/master/utils.py (available with code) which contains utility functions to create the neural network and load the weights assoiated with it.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.models import Model
from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.engine.topology import Layer
from keras import backend as K
import cv2
import os
import numpy as np
from numpy import genfromtxt
import pandas as pd
import tensorflow as tf
from utils import LRN2D
import utils
import sys
# %load_ext autoreload
# %autoreload 2

np.set_printoptions(threshold=sys.maxsize)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Contructing the neural network model
# The model here constructed is based on FaceNet's Inception model.
#
# The implementation of model is available at: https://github.com/iwantooxxoox/Keras-OpenFace

# %%
myInput = Input(shape=(96, 96, 3))

x = ZeroPadding2D(padding=(3, 3), input_shape=(96, 96, 3))(myInput)
x = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn1')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)
x = Lambda(LRN2D, name='lrn_1')(x)
x = Conv2D(64, (1, 1), name='conv2')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn2')(x)
x = Activation('relu')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = Conv2D(192, (3, 3), name='conv3')(x)
x = BatchNormalization(axis=3, epsilon=0.00001, name='bn3')(x)
x = Activation('relu')(x)
x = Lambda(LRN2D, name='lrn_2')(x)
x = ZeroPadding2D(padding=(1, 1))(x)
x = MaxPooling2D(pool_size=3, strides=2)(x)

# Inception3a
inception_3a_3x3 = Conv2D(96, (1, 1), name='inception_3a_3x3_conv1')(x)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn1')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)
inception_3a_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3)
inception_3a_3x3 = Conv2D(128, (3, 3), name='inception_3a_3x3_conv2')(inception_3a_3x3)
inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn2')(inception_3a_3x3)
inception_3a_3x3 = Activation('relu')(inception_3a_3x3)

inception_3a_5x5 = Conv2D(16, (1, 1), name='inception_3a_5x5_conv1')(x)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn1')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)
inception_3a_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5)
inception_3a_5x5 = Conv2D(32, (5, 5), name='inception_3a_5x5_conv2')(inception_3a_5x5)
inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn2')(inception_3a_5x5)
inception_3a_5x5 = Activation('relu')(inception_3a_5x5)

inception_3a_pool = MaxPooling2D(pool_size=3, strides=2)(x)
inception_3a_pool = Conv2D(32, (1, 1), name='inception_3a_pool_conv')(inception_3a_pool)
inception_3a_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_pool_bn')(inception_3a_pool)
inception_3a_pool = Activation('relu')(inception_3a_pool)
inception_3a_pool = ZeroPadding2D(padding=((3, 4), (3, 4)))(inception_3a_pool)

inception_3a_1x1 = Conv2D(64, (1, 1), name='inception_3a_1x1_conv')(x)
inception_3a_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_1x1_bn')(inception_3a_1x1)
inception_3a_1x1 = Activation('relu')(inception_3a_1x1)

inception_3a = concatenate([inception_3a_3x3, inception_3a_5x5, inception_3a_pool, inception_3a_1x1], axis=3)

# Inception3b
inception_3b_3x3 = Conv2D(96, (1, 1), name='inception_3b_3x3_conv1')(inception_3a)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn1')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)
inception_3b_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3)
inception_3b_3x3 = Conv2D(128, (3, 3), name='inception_3b_3x3_conv2')(inception_3b_3x3)
inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn2')(inception_3b_3x3)
inception_3b_3x3 = Activation('relu')(inception_3b_3x3)

inception_3b_5x5 = Conv2D(32, (1, 1), name='inception_3b_5x5_conv1')(inception_3a)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn1')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)
inception_3b_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5)
inception_3b_5x5 = Conv2D(64, (5, 5), name='inception_3b_5x5_conv2')(inception_3b_5x5)
inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn2')(inception_3b_5x5)
inception_3b_5x5 = Activation('relu')(inception_3b_5x5)

inception_3b_pool = Lambda(lambda x: x**2, name='power2_3b')(inception_3a)
inception_3b_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: x*9, name='mult9_3b')(inception_3b_pool)
inception_3b_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_3b')(inception_3b_pool)
inception_3b_pool = Conv2D(64, (1, 1), name='inception_3b_pool_conv')(inception_3b_pool)
inception_3b_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_pool_bn')(inception_3b_pool)
inception_3b_pool = Activation('relu')(inception_3b_pool)
inception_3b_pool = ZeroPadding2D(padding=(4, 4))(inception_3b_pool)

inception_3b_1x1 = Conv2D(64, (1, 1), name='inception_3b_1x1_conv')(inception_3a)
inception_3b_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_1x1_bn')(inception_3b_1x1)
inception_3b_1x1 = Activation('relu')(inception_3b_1x1)

inception_3b = concatenate([inception_3b_3x3, inception_3b_5x5, inception_3b_pool, inception_3b_1x1], axis=3)

# Inception3c
inception_3c_3x3 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_3x3',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))

inception_3c_5x5 = utils.conv2d_bn(inception_3b,
                                   layer='inception_3c_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))

inception_3c_pool = MaxPooling2D(pool_size=3, strides=2)(inception_3b)
inception_3c_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_3c_pool)

inception_3c = concatenate([inception_3c_3x3, inception_3c_5x5, inception_3c_pool], axis=3)

#inception 4a
inception_4a_3x3 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=192,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_4a_5x5 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_5x5',
                                   cv1_out=32,
                                   cv1_filter=(1, 1),
                                   cv2_out=64,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(1, 1),
                                   padding=(2, 2))

inception_4a_pool = Lambda(lambda x: x**2, name='power2_4a')(inception_3c)
inception_4a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: x*9, name='mult9_4a')(inception_4a_pool)
inception_4a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_4a')(inception_4a_pool)
inception_4a_pool = utils.conv2d_bn(inception_4a_pool,
                                   layer='inception_4a_pool',
                                   cv1_out=128,
                                   cv1_filter=(1, 1),
                                   padding=(2, 2))
inception_4a_1x1 = utils.conv2d_bn(inception_3c,
                                   layer='inception_4a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_4a = concatenate([inception_4a_3x3, inception_4a_5x5, inception_4a_pool, inception_4a_1x1], axis=3)

#inception4e
inception_4e_3x3 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_3x3',
                                   cv1_out=160,
                                   cv1_filter=(1, 1),
                                   cv2_out=256,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(2, 2),
                                   padding=(1, 1))
inception_4e_5x5 = utils.conv2d_bn(inception_4a,
                                   layer='inception_4e_5x5',
                                   cv1_out=64,
                                   cv1_filter=(1, 1),
                                   cv2_out=128,
                                   cv2_filter=(5, 5),
                                   cv2_strides=(2, 2),
                                   padding=(2, 2))
inception_4e_pool = MaxPooling2D(pool_size=3, strides=2)(inception_4a)
inception_4e_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_4e_pool)

inception_4e = concatenate([inception_4e_3x3, inception_4e_5x5, inception_4e_pool], axis=3)

#inception5a
inception_5a_3x3 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))

inception_5a_pool = Lambda(lambda x: x**2, name='power2_5a')(inception_4e)
inception_5a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: x*9, name='mult9_5a')(inception_5a_pool)
inception_5a_pool = Lambda(lambda x: K.sqrt(x), name='sqrt_5a')(inception_5a_pool)
inception_5a_pool = utils.conv2d_bn(inception_5a_pool,
                                   layer='inception_5a_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   padding=(1, 1))
inception_5a_1x1 = utils.conv2d_bn(inception_4e,
                                   layer='inception_5a_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))

inception_5a = concatenate([inception_5a_3x3, inception_5a_pool, inception_5a_1x1], axis=3)

#inception_5b
inception_5b_3x3 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_3x3',
                                   cv1_out=96,
                                   cv1_filter=(1, 1),
                                   cv2_out=384,
                                   cv2_filter=(3, 3),
                                   cv2_strides=(1, 1),
                                   padding=(1, 1))
inception_5b_pool = MaxPooling2D(pool_size=3, strides=2)(inception_5a)
inception_5b_pool = utils.conv2d_bn(inception_5b_pool,
                                   layer='inception_5b_pool',
                                   cv1_out=96,
                                   cv1_filter=(1, 1))
inception_5b_pool = ZeroPadding2D(padding=(1, 1))(inception_5b_pool)

inception_5b_1x1 = utils.conv2d_bn(inception_5a,
                                   layer='inception_5b_1x1',
                                   cv1_out=256,
                                   cv1_filter=(1, 1))
inception_5b = concatenate([inception_5b_3x3, inception_5b_pool, inception_5b_1x1], axis=3)

av_pool = AveragePooling2D(pool_size=(3, 3), strides=(1, 1))(inception_5b)
reshape_layer = Flatten()(av_pool)
dense_layer = Dense(128, name='dense_layer')(reshape_layer)
norm_layer = Lambda(lambda  x: K.l2_normalize(x, axis=1), name='norm_layer')(dense_layer)


# Final Model
model = Model(inputs=[myInput], outputs=norm_layer)

# %% [markdown]
# # Loading the model with pretrained weights
#
# FaceNet is trained by minimizing the triplet loss. I will be  loading a previously trained model. weights are avaiable at https://github.com/iwantooxxoox/Keras-OpenFace in the "weights" folder which is also provided in this source.
#
# This can take a couple of minutes to execute and depends on the speed of your machine.

# %%
# Load weights from csv files (which was exported from Openface torch model)
weights = utils.weights
weights_dict = utils.load_weights()

# Set layer weights of the model
for name in weights:
    if model.get_layer(name) != None:
        model.get_layer(name).set_weights(weights_dict[name])
    elif model.get_layer(name) != None:
        model.get_layer(name).set_weights(weights_dict[name])

# %% [markdown]
# ## About <font color=blue>image_to_embedding</font> function
# When the model is loaded with pre trained weights, then we can create the **128 dimensional embedding vectors** for all the face images stored in the "images" folder. **"image_to_embedding"** function pass an image to the Inception network to generate the embedding vector.

# %%
def image_to_embedding(image, model):
    #image = cv2.resize(image, (96, 96), interpolation=cv2.INTER_AREA) 
    image = cv2.resize(image, (96, 96)) 
    img = image[...,::-1]
    img = np.around(np.transpose(img, (0,1,2))/255.0, decimals=12)
    x_train = np.array([img])
    embedding = model.predict_on_batch(x_train)
    return embedding

# %% [markdown]
# ## About <font color=blue>recognize_face</font> function
# This function calculate similarity between the captured image and the images that are already been stored. It passes the image to the trained neural network to generate its embedding vector. Which is then compared with all the embedding vectors of the images stored by calculating L2 Euclidean distance.
#
# If the minimum L2 distance between two embeddings is less than a threshpld (here I have taken the threashhold as .68 (which can be adjusted) then we have a match.

# %%
def recognize_face(face_image, input_embeddings, model):

    embedding = image_to_embedding(face_image, model)
    
    minimum_distance = 200
    name = None
    
    # Loop over  names and encodings.
    for (input_name, input_embedding) in input_embeddings.items():
        
       
        euclidean_distance = np.linalg.norm(embedding-input_embedding)
        

        print('Euclidean distance from %s is %s' %(input_name, euclidean_distance))

        
        if euclidean_distance < minimum_distance:
            minimum_distance = euclidean_distance
            name = input_name
    
    if minimum_distance < .68:
        return str(name)
    else:
        return None

# %% [markdown]
# ## About <font color=blue>create_input_image_embeddings</font> function
# This function generates 128 dimensional image ebeddings of all the images stored in the "images" directory by feed forwarding the images to a trained neural network. It creates a dictionary with key as the name of the face and value as embedding
#
#
# ## About <font color=blue>recognize_faces_in_cam</font> function
# This function capture image from the webcam, detect a face in it and crop the image to have a face only, which is then passed to recognize_face function.

# %%
import glob

def create_input_image_embeddings():
    input_embeddings = {}

    for file in glob.glob("images/*"):
        person_name = os.path.splitext(os.path.basename(file))[0]
        image_file = cv2.imread(file, 1)
        input_embeddings[person_name] = image_to_embedding(image_file, model)

    return input_embeddings

def recognize_faces_in_cam(input_embeddings):
    

    cv2.namedWindow("Face Recognizer")
    vc = cv2.VideoCapture(0)
   

    font = cv2.FONT_HERSHEY_SIMPLEX
    face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    
    
    while vc.isOpened():
        _, frame = vc.read()
        img = frame
        height, width, channels = frame.shape

        
        
        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)

        # Loop through all the faces detected 
        identities = []
        for (x, y, w, h) in faces:
            x1 = x
            y1 = y
            x2 = x+w
            y2 = y+h

           
            
            face_image = frame[max(0, y1):min(height, y2), max(0, x1):min(width, x2)]    
            identity = recognize_face(face_image, input_embeddings, model)
            
            

            if identity is not None:
                img = cv2.rectangle(frame,(x1, y1),(x2, y2),(255,255,255),2)
                cv2.putText(img, str(identity), (x1+5,y1-5), font, 1, (255,255,255), 2)
        
        key = cv2.waitKey(100)
        cv2.imshow("Face Recognizer", img)

        if key == 27: # exit on ESC
            break
    vc.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ## Capturing the face image
# Following code captures 10 face images of the person. They all are stored in **"images"** folder with the name User_1 to User_10. Select a good captured image from the set of 10 images. Rename it with the name of person and delete rest of them. This image will be used for recognizing the the identity of the person using one shot learning.

# %%
cv2.CAP_PROP_FPS
# Out:
# 5

# %%
cam = cv2.VideoCapture(0)
# cam.set(cv2.CAP_PROP_FPS, 60)
face_detector = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

count = 0
while(True):
#     cam.set(cv2.CAP_PROP_FPS, 60)
    ret, img = cam.read()
    #gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_detector.detectMultiScale(img, 1.3, 5)
    for (x,y,w,h) in faces:
        x1 = x
        y1 = y
        x2 = x+w
        y2 = y+h
        cv2.rectangle(img, (x1,y1), (x2,y2), (255,255,255), 2)     
        count += 1
        # Save the captured image into the datasets folder
        cv2.imwrite("images/User_" + str(count) + ".jpg", img[y1:y2,x1:x2])
        cv2.imshow('image', img)
    k = cv2.waitKey(200) & 0xff # Press 'ESC' for exiting video
    if k == 27:
        break
    elif count >= 10: # Take 30 face sample and stop video
         break
cam.release()
cv2.destroyAllWindows()

# %% [markdown]
# # Lets run the face recognizer program :-)

# %%
input_embeddings = create_input_image_embeddings()
recognize_faces_in_cam(input_embeddings)
# Out:
# Euclidean distance from akshat is 0.9961551
# Euclidean distance from siddhant is 0.6063876
# Euclidean distance from akshat is 0.6398619
# Euclidean distance from siddhant is 0.75142807
# Euclidean distance from akshat is 0.91918963
# Euclidean distance from siddhant is 0.6126018
# Euclidean distance from akshat is 0.61817396
# Euclidean distance from siddhant is 0.7991848
# Euclidean distance from akshat is 0.9793691
# Euclidean distance from siddhant is 0.47693905
# Euclidean distance from akshat is 0.43765032
# Euclidean distance from siddhant is 0.86392
# Euclidean distance from akshat is 0.941757
# Euclidean distance from siddhant is 0.624506
# Euclidean distance from akshat is 0.6321198
# Euclidean distance from siddhant is 0.76165867
# Euclidean distance from akshat is 1.0514004
# Euclidean distance from siddhant is 0.5501664
# Euclidean distance from akshat is 0.47218737
# Euclidean distance from siddhant is 0.9207254
# Euclidean distance from akshat is 1.0873268
# Euclidean distance from siddhant is 0.54069495
# Euclidean distance from akshat is 0.5552429
# Euclidean distance from siddhant is 0.88748145
# Euclidean distance from akshat is 0.99532485
# Euclidean distance from siddhant is 0.5851423
# Euclidean distance from akshat is 0.5079085
# Euclidean distance from siddhant is 0.929343
# Euclidean distance from akshat is 1.1522487
# Euclidean distance from siddhant is 0.5983297
# Euclidean distance from akshat is 0.5744691
# Euclidean distance from siddhant is 0.88005877
# Euclidean distance from akshat is 0.9118496
# Euclidean distance from siddhant is 0.6729895
# Euclidean distance from akshat is 0.5656124
# Euclidean distance from siddhant is 0.8319433
# Euclidean distance from akshat is 0.74343336
# Euclidean distance from siddhant is 0.7008391
# Euclidean distance from akshat is 0.683347
# Euclidean distance from siddhant is 0.8415671
# Euclidean distance from akshat is 1.1657456
# Euclidean distance from siddhant is 0.6062396
# Euclidean distance from akshat is 0.5508859
# Euclidean distance from siddhant is 0.9006827
# Euclidean distance from akshat is 1.2539759
# Euclidean distance from siddhant is 0.689737
# Euclidean distance from akshat is 0.57882994
# Euclidean distance from siddhant is 0.8383352
# Euclidean distance from akshat is 0.53984755
# Euclidean distance from siddhant is 0.98742545
# Euclidean distance from akshat is 1.1087153
# Euclidean distance from siddhant is 0.664763
# Euclidean distance from akshat is 0.58396566
# Euclidean distance from siddhant is 0.9567145
# Euclidean distance from akshat is 0.6295011
# Euclidean distance from siddhant is 0.916966
# Euclidean distance from akshat is 0.5343011
# Euclidean distance from siddhant is 0.9147118
# Euclidean distance from akshat is 0.7312749
# Euclidean distance from siddhant is 0.8520358
# Euclidean distance from akshat is 0.63146394
# Euclidean distance from siddhant is 0.9430796
# Euclidean distance from akshat is 0.6327589
# Euclidean distance from siddhant is 0.97603893
# Euclidean distance from akshat is 0.7626088
# Euclidean distance from siddhant is 0.91832966
# Euclidean distance from akshat is 0.78120255
# Euclidean distance from siddhant is 1.0442911
# Euclidean distance from akshat is 0.7028562
# Euclidean distance from siddhant is 0.9634968
# Euclidean distance from akshat is 0.81132025
# Euclidean distance from siddhant is 0.86723435
# Euclidean distance from akshat is 1.0078572
# Euclidean distance from siddhant is 0.9774582
# Euclidean distance from akshat is 0.93605596
# Euclidean distance from siddhant is 0.89478874
# Euclidean distance from akshat is 1.0682278
# Euclidean distance from siddhant is 0.87279063
# Euclidean distance from akshat is 1.0871722
# Euclidean distance from siddhant is 0.77821225
# Euclidean distance from akshat is 0.68902075
# Euclidean distance from siddhant is 1.0381294
# Euclidean distance from akshat is 1.1289008
# Euclidean distance from siddhant is 0.7361826
# Euclidean distance from akshat is 1.1270509
# Euclidean distance from siddhant is 0.7964939
# Euclidean distance from akshat is 0.90318584
# Euclidean distance from siddhant is 0.68361205
# Euclidean distance from akshat is 0.7746389
# Euclidean distance from siddhant is 0.7926249
# Euclidean distance from akshat is 0.71122676
# Euclidean distance from siddhant is 1.101468
# Euclidean distance from akshat is 0.85624576
# Euclidean distance from siddhant is 0.8881679
# Euclidean distance from akshat is 0.8642276
# Euclidean distance from siddhant is 0.84708524
# Euclidean distance from akshat is 0.8971375
# Euclidean distance from siddhant is 0.80678254
# Euclidean distance from akshat is 0.7363519
# Euclidean distance from siddhant is 0.96118003
# Euclidean distance from akshat is 0.84149694
# Euclidean distance from siddhant is 0.84404373
# Euclidean distance from akshat is 0.639213
# Euclidean distance from siddhant is 0.93481344
# Euclidean distance from akshat is 0.89438814
# Euclidean distance from siddhant is 0.91160375
# Euclidean distance from akshat is 0.65971965
# Euclidean distance from siddhant is 0.9797306
# Euclidean distance from akshat is 0.9188496
# Euclidean distance from siddhant is 0.82195866
# Euclidean distance from akshat is 0.6498648
# Euclidean distance from siddhant is 0.99239224
# Euclidean distance from akshat is 0.88835996
# Euclidean distance from siddhant is 0.8683501
# Euclidean distance from akshat is 0.4562666
# Euclidean distance from siddhant is 0.91589963
# Euclidean distance from akshat is 0.9202065
# Euclidean distance from siddhant is 0.8408465
# Euclidean distance from akshat is 0.50327075
# Euclidean distance from siddhant is 0.82345
# Euclidean distance from akshat is 1.0591112
# Euclidean distance from siddhant is 0.7353999
# Euclidean distance from akshat is 0.6023257
# Euclidean distance from siddhant is 0.9477339
# Euclidean distance from akshat is 0.97983813
# Euclidean distance from siddhant is 0.7790519
# Euclidean distance from akshat is 0.6291926
# Euclidean distance from siddhant is 0.9210797
# Euclidean distance from akshat is 0.7322672
# Euclidean distance from siddhant is 0.9825536
# Euclidean distance from akshat is 0.90855205
# Euclidean distance from siddhant is 0.74103016
# Euclidean distance from akshat is 1.0328851
# Euclidean distance from siddhant is 0.83375823
# Euclidean distance from akshat is 0.5289165
# Euclidean distance from siddhant is 0.876052
# Euclidean distance from akshat is 0.86955416
# Euclidean distance from siddhant is 0.91956633
# Euclidean distance from akshat is 0.6025083
# Euclidean distance from siddhant is 1.0259967
# Euclidean distance from akshat is 0.6621102
# Euclidean distance from siddhant is 1.0435221
# Euclidean distance from akshat is 0.63819486
# Euclidean distance from siddhant is 0.99900395
# Euclidean distance from akshat is 0.61648136
# Euclidean distance from siddhant is 0.9872722
# Euclidean distance from akshat is 0.58583826
# Euclidean distance from siddhant is 1.0149031
# Euclidean distance from akshat is 0.54331255
# Euclidean distance from siddhant is 0.9601863
# Euclidean distance from akshat is 0.6109703
# Euclidean distance from siddhant is 1.0139227
# Euclidean distance from akshat is 1.1504636
# Euclidean distance from siddhant is 0.7681875
# Euclidean distance from akshat is 0.38244444
# Euclidean distance from siddhant is 0.9887585
# Euclidean distance from akshat is 0.6536771
# Euclidean distance from siddhant is 0.96864
# Euclidean distance from akshat is 1.1782392
# Euclidean distance from siddhant is 0.7938637
# Euclidean distance from akshat is 0.5772108
# Euclidean distance from siddhant is 0.9599027
# Euclidean distance from akshat is 0.60423803
# Euclidean distance from siddhant is 0.90894824
# Euclidean distance from akshat is 1.0834879
# Euclidean distance from siddhant is 0.9392733
# Euclidean distance from akshat is 0.62682104
# Euclidean distance from siddhant is 0.9268142
# Euclidean distance from akshat is 0.57271785
# Euclidean distance from siddhant is 0.9690902
# Euclidean distance from akshat is 0.6210131
# Euclidean distance from siddhant is 1.0330684
# Euclidean distance from akshat is 0.7682606
# Euclidean distance from siddhant is 0.85253793
# Euclidean distance from akshat is 0.60271555
# Euclidean distance from siddhant is 0.92545104
# Euclidean distance from akshat is 0.5847774
# Euclidean distance from siddhant is 0.983786
# Euclidean distance from akshat is 0.5790883
# Euclidean distance from siddhant is 0.9514759
# Euclidean distance from akshat is 0.74269176
# Euclidean distance from siddhant is 0.77158725
# Euclidean distance from akshat is 0.6799469
# Euclidean distance from siddhant is 0.8710779
# Euclidean distance from akshat is 0.5639888
# Euclidean distance from siddhant is 0.9110458
# Euclidean distance from akshat is 0.5486853
# Euclidean distance from siddhant is 0.9633735
# Euclidean distance from akshat is 0.615485
# Euclidean distance from siddhant is 0.9000475
# Euclidean distance from akshat is 0.6568046
# Euclidean distance from siddhant is 0.9429152
# Euclidean distance from akshat is 0.6818196
# Euclidean distance from siddhant is 0.9132178
# Euclidean distance from akshat is 0.623358
# Euclidean distance from siddhant is 0.96033263
# Euclidean distance from akshat is 0.62529045
# Euclidean distance from siddhant is 0.90207386
# Euclidean distance from akshat is 0.48706773
# Euclidean distance from siddhant is 0.9543322
# Euclidean distance from akshat is 0.54390067
# Euclidean distance from siddhant is 0.880225
# Euclidean distance from akshat is 0.56600475
# Euclidean distance from siddhant is 0.845457
# Euclidean distance from akshat is 0.61623657
# Euclidean distance from siddhant is 0.7274806
# Euclidean distance from akshat is 0.66906935
# Euclidean distance from siddhant is 0.8437233
# Euclidean distance from akshat is 0.6137467
# Euclidean distance from siddhant is 0.9286874
# Euclidean distance from akshat is 0.54843503
# Euclidean distance from siddhant is 0.89074457
# Euclidean distance from akshat is 0.45884907
# Euclidean distance from siddhant is 1.0328078
# Euclidean distance from akshat is 0.4801176
# Euclidean distance from siddhant is 1.0105854
# Euclidean distance from akshat is 0.4590692
# Euclidean distance from siddhant is 0.93773896
# Euclidean distance from akshat is 0.5205548
# Euclidean distance from siddhant is 0.94573694
# Euclidean distance from akshat is 0.9088138
# Euclidean distance from siddhant is 0.6469633
# Euclidean distance from akshat is 0.92748994
# Euclidean distance from siddhant is 0.64624596
# Euclidean distance from akshat is 0.47311142
# Euclidean distance from siddhant is 0.9229201
# Euclidean distance from akshat is 0.8229695
# Euclidean distance from siddhant is 0.8569497
# Euclidean distance from akshat is 1.0038652
# Euclidean distance from siddhant is 0.6815198
# Euclidean distance from akshat is 0.978109
# Euclidean distance from siddhant is 0.827007
# Euclidean distance from akshat is 0.9204419
# Euclidean distance from siddhant is 0.7769541
# Euclidean distance from akshat is 0.9144464
# Euclidean distance from siddhant is 0.6633555
# Euclidean distance from akshat is 1.03129
# Euclidean distance from siddhant is 0.7722696
# Euclidean distance from akshat is 0.9407013
# Euclidean distance from siddhant is 0.7720687
# Euclidean distance from akshat is 0.44099545
# Euclidean distance from siddhant is 0.7822956
# Euclidean distance from akshat is 0.91926557
# Euclidean distance from siddhant is 0.7529909
# Euclidean distance from akshat is 0.36999097
# Euclidean distance from siddhant is 0.9625579
# Euclidean distance from akshat is 0.9061289
# Euclidean distance from siddhant is 0.7358275
# Euclidean distance from akshat is 0.38871843
# Euclidean distance from siddhant is 0.9073047
# Euclidean distance from akshat is 0.9257718
# Euclidean distance from siddhant is 0.8893481
# Euclidean distance from akshat is 0.48425636
# Euclidean distance from siddhant is 0.8159201
# Euclidean distance from akshat is 0.8798448
# Euclidean distance from siddhant is 0.9164624
# Euclidean distance from akshat is 0.3437903
# Euclidean distance from siddhant is 0.96510786
# Euclidean distance from akshat is 0.4194726
# Euclidean distance from siddhant is 0.96447253
# Euclidean distance from akshat is 0.79150057
# Euclidean distance from siddhant is 0.9381751
# Euclidean distance from akshat is 0.6324504
# Euclidean distance from siddhant is 0.8032748
# Euclidean distance from akshat is 1.025541
# Euclidean distance from siddhant is 0.72125787
# Euclidean distance from akshat is 1.0021901
# Euclidean distance from siddhant is 0.87577766
# Euclidean distance from akshat is 0.9988619
# Euclidean distance from siddhant is 0.83074415
# Euclidean distance from akshat is 0.9428336
# Euclidean distance from siddhant is 0.85346377
# Euclidean distance from akshat is 0.96741116
# Euclidean distance from siddhant is 0.82674176
# Euclidean distance from akshat is 0.8159969
# Euclidean distance from siddhant is 0.9432698
# Euclidean distance from akshat is 0.7133733
# Euclidean distance from siddhant is 0.6967467
# Euclidean distance from akshat is 0.7882272
# Euclidean distance from siddhant is 0.7957384
# Euclidean distance from akshat is 0.9956132
# Euclidean distance from siddhant is 0.75234
# Euclidean distance from akshat is 1.1693265
# Euclidean distance from siddhant is 0.7763394
# Euclidean distance from akshat is 1.0388288
# Euclidean distance from siddhant is 0.7848686
# Euclidean distance from akshat is 0.98667836
# Euclidean distance from siddhant is 0.97778344
# Euclidean distance from akshat is 0.9721432
# Euclidean distance from siddhant is 1.0103325
# Euclidean distance from akshat is 0.86609113
# Euclidean distance from siddhant is 0.91032
# Euclidean distance from akshat is 0.7878291
# Euclidean distance from siddhant is 0.88096845
# Euclidean distance from akshat is 0.93299735
# Euclidean distance from siddhant is 0.74897194
# Euclidean distance from akshat is 0.89436305
# Euclidean distance from siddhant is 0.81078076
# Euclidean distance from akshat is 0.91635525
# Euclidean distance from siddhant is 0.92810804
# Euclidean distance from akshat is 0.796288
# Euclidean distance from siddhant is 0.9741579
# Euclidean distance from akshat is 0.48299512
# Euclidean distance from siddhant is 0.96866345
# Euclidean distance from akshat is 0.57270664
# Euclidean distance from siddhant is 0.9587105
# Euclidean distance from akshat is 0.7287782
# Euclidean distance from siddhant is 1.125525
# Euclidean distance from akshat is 0.65729624
# Euclidean distance from siddhant is 0.97703135
# Euclidean distance from akshat is 0.6630596
# Euclidean distance from siddhant is 0.93918616
# Euclidean distance from akshat is 0.68107206
# Euclidean distance from siddhant is 1.0970471
# Euclidean distance from akshat is 0.6048782
# Euclidean distance from siddhant is 1.0720252
# Euclidean distance from akshat is 0.70019364
# Euclidean distance from siddhant is 1.0929854
# Euclidean distance from akshat is 0.61514527
# Euclidean distance from siddhant is 1.1022966
# Euclidean distance from akshat is 0.64031625
# Euclidean distance from siddhant is 0.9830264
# Euclidean distance from akshat is 0.6873899
# Euclidean distance from siddhant is 0.97804785
# Euclidean distance from akshat is 0.54928076
# Euclidean distance from siddhant is 1.0314344
# Euclidean distance from akshat is 0.56470484
# Euclidean distance from siddhant is 0.9973349
# Euclidean distance from akshat is 0.70202625
# Euclidean distance from siddhant is 0.88102263
# Euclidean distance from akshat is 0.52536714
# Euclidean distance from siddhant is 0.99306864
# Euclidean distance from akshat is 0.45220518
# Euclidean distance from siddhant is 0.9868323
# Euclidean distance from akshat is 0.8604102
# Euclidean distance from siddhant is 0.9036263
# Euclidean distance from akshat is 0.37014532
# Euclidean distance from siddhant is 0.8592677
# Euclidean distance from akshat is 0.46659076
# Euclidean distance from siddhant is 1.0574083
# Euclidean distance from akshat is 0.83777416
# Euclidean distance from siddhant is 0.7716618
# Euclidean distance from akshat is 0.5129118
# Euclidean distance from siddhant is 1.0929143
# Euclidean distance from akshat is 0.52421576
# Euclidean distance from siddhant is 1.0540644
# Euclidean distance from akshat is 0.68948495
# Euclidean distance from siddhant is 0.9751191
# Euclidean distance from akshat is 0.4554638
# Euclidean distance from siddhant is 0.9581723
# Euclidean distance from akshat is 0.50365555
# Euclidean distance from siddhant is 0.8291992
# Euclidean distance from akshat is 0.44049415
# Euclidean distance from siddhant is 1.0444006
# Euclidean distance from akshat is 0.48044336
# Euclidean distance from siddhant is 1.0135835
# Euclidean distance from akshat is 0.47932246
# Euclidean distance from siddhant is 0.87315685
# Euclidean distance from akshat is 0.33043635
# Euclidean distance from siddhant is 0.8974172
# Euclidean distance from akshat is 0.5980861
# Euclidean distance from siddhant is 0.83184886
# Euclidean distance from akshat is 0.51854426
# Euclidean distance from siddhant is 0.84437984
# Euclidean distance from akshat is 0.48971012
# Euclidean distance from siddhant is 0.87330335
# Euclidean distance from akshat is 0.4204766
# Euclidean distance from siddhant is 0.98093414
# Euclidean distance from akshat is 0.5363266
# Euclidean distance from siddhant is 1.0717573
# Euclidean distance from akshat is 0.41989058
# Euclidean distance from siddhant is 1.0251138
# Euclidean distance from akshat is 0.42390153
# Euclidean distance from siddhant is 1.0805805
# Euclidean distance from akshat is 0.4290462
# Euclidean distance from siddhant is 1.0331262
# Euclidean distance from akshat is 0.38184175
# Euclidean distance from siddhant is 1.0485315
# Euclidean distance from akshat is 0.3089361
# Euclidean distance from siddhant is 0.91522384
# Euclidean distance from akshat is 0.32607275
# Euclidean distance from siddhant is 0.97884005
# Euclidean distance from akshat is 0.37298355
# Euclidean distance from siddhant is 1.0397809
# Euclidean distance from akshat is 0.36190397
# Euclidean distance from siddhant is 1.027777
# Euclidean distance from akshat is 0.31754747
# Euclidean distance from siddhant is 0.989117
# Euclidean distance from akshat is 0.29423335
# Euclidean distance from siddhant is 0.9537152
# Euclidean distance from akshat is 0.39656556
# Euclidean distance from siddhant is 0.79914457
# Euclidean distance from akshat is 0.88932914
# Euclidean distance from siddhant is 0.73829585
# Euclidean distance from akshat is 0.23425148
# Euclidean distance from siddhant is 0.9323381
# Euclidean distance from akshat is 0.5785009
# Euclidean distance from siddhant is 0.73328716
# Euclidean distance from akshat is 0.56427836
# Euclidean distance from siddhant is 0.7013746
# Euclidean distance from akshat is 0.6938949
# Euclidean distance from siddhant is 0.83213925
# Euclidean distance from akshat is 0.4161437
# Euclidean distance from siddhant is 0.83488375
# Euclidean distance from akshat is 0.36319104
# Euclidean distance from siddhant is 0.924868
# Euclidean distance from akshat is 0.7019608
# Euclidean distance from siddhant is 1.0518806
# Euclidean distance from akshat is 0.88081324
# Euclidean distance from siddhant is 0.8610742
# Euclidean distance from akshat is 0.80765545
# Euclidean distance from siddhant is 0.74429524
# Euclidean distance from akshat is 1.0200185
# Euclidean distance from siddhant is 0.9117029
# Euclidean distance from akshat is 0.54971474
# Euclidean distance from siddhant is 0.9361673
# Euclidean distance from akshat is 1.0930603
# Euclidean distance from siddhant is 0.82626337
# Euclidean distance from akshat is 0.44059452
# Euclidean distance from siddhant is 0.9400813
# Euclidean distance from akshat is 1.3296475
# Euclidean distance from siddhant is 1.1402185
# Euclidean distance from akshat is 1.1248776
# Euclidean distance from siddhant is 1.1004221
# Euclidean distance from akshat is 1.3573576
# Euclidean distance from siddhant is 1.1396692
# Euclidean distance from akshat is 1.2549938
# Euclidean distance from siddhant is 1.0683218
# Euclidean distance from akshat is 1.1496727
# Euclidean distance from siddhant is 1.0581504
# Euclidean distance from akshat is 1.1035734
# Euclidean distance from siddhant is 0.961582
# Euclidean distance from akshat is 0.40620324
# Euclidean distance from siddhant is 0.93457335
# Euclidean distance from akshat is 1.2527357
# Euclidean distance from siddhant is 1.0677626
# Euclidean distance from akshat is 1.2866442
# Euclidean distance from siddhant is 1.1803726
# Euclidean distance from akshat is 1.1889503
# Euclidean distance from siddhant is 1.1337155
# Euclidean distance from akshat is 0.82984996
# Euclidean distance from siddhant is 0.8841253
# Euclidean distance from akshat is 0.47531626
# Euclidean distance from siddhant is 0.90762216
# Euclidean distance from akshat is 0.4157345
# Euclidean distance from siddhant is 0.9080204
# Euclidean distance from akshat is 0.44349825
# Euclidean distance from siddhant is 0.93268603
# Euclidean distance from akshat is 0.5045283
# Euclidean distance from siddhant is 0.88717836
# Euclidean distance from akshat is 0.42207363
# Euclidean distance from siddhant is 0.93998647
# Euclidean distance from akshat is 0.46033585
# Euclidean distance from siddhant is 0.89180297
# Euclidean distance from akshat is 0.349495
# Euclidean distance from siddhant is 0.87780774
# Euclidean distance from akshat is 0.45350188
# Euclidean distance from siddhant is 1.0127387
# Euclidean distance from akshat is 0.36454436
# Euclidean distance from siddhant is 0.9115151
# Euclidean distance from akshat is 0.43574023
# Euclidean distance from siddhant is 1.0029982
# Euclidean distance from akshat is 0.39651537
# Euclidean distance from siddhant is 0.9418663
# Euclidean distance from akshat is 0.4172728
# Euclidean distance from siddhant is 1.0073297
# Euclidean distance from akshat is 0.42339784
# Euclidean distance from siddhant is 1.0531006
# Euclidean distance from akshat is 0.44191536
# Euclidean distance from siddhant is 0.97287893
# Euclidean distance from akshat is 0.55817986
# Euclidean distance from siddhant is 1.0386947
# Euclidean distance from akshat is 0.65770674
# Euclidean distance from siddhant is 0.92538065
# Euclidean distance from akshat is 0.61866593
# Euclidean distance from siddhant is 1.0476556
# Euclidean distance from akshat is 0.52160233
# Euclidean distance from siddhant is 1.0489311
# Euclidean distance from akshat is 0.53429145
# Euclidean distance from siddhant is 1.0244216
# Euclidean distance from akshat is 0.52891135
# Euclidean distance from siddhant is 1.0761431
# Euclidean distance from akshat is 0.53321517
# Euclidean distance from siddhant is 0.9921788
# Euclidean distance from akshat is 1.0105542
# Euclidean distance from siddhant is 0.8278925
# Euclidean distance from akshat is 0.55831003
# Euclidean distance from siddhant is 0.98332834
# Euclidean distance from akshat is 0.89105606
# Euclidean distance from siddhant is 0.87020516
# Euclidean distance from akshat is 0.44541815
# Euclidean distance from siddhant is 0.9636003
# Euclidean distance from akshat is 1.0362765
# Euclidean distance from siddhant is 0.86997885
# Euclidean distance from akshat is 0.61546934
# Euclidean distance from siddhant is 0.9136279
# Euclidean distance from akshat is 0.8310676
# Euclidean distance from siddhant is 0.9878892
# Euclidean distance from akshat is 0.9028019
# Euclidean distance from siddhant is 0.93378824
# Euclidean distance from akshat is 0.8577442
# Euclidean distance from siddhant is 0.8662365
# Euclidean distance from akshat is 0.6897302
# Euclidean distance from siddhant is 0.9038071
# Euclidean distance from akshat is 0.8802112
# Euclidean distance from siddhant is 0.9840199
# Euclidean distance from akshat is 0.56794566
# Euclidean distance from siddhant is 0.9755275
# Euclidean distance from akshat is 0.8203635
# Euclidean distance from siddhant is 1.1213578
# Euclidean distance from akshat is 0.9162255
# Euclidean distance from siddhant is 1.1450351
# Euclidean distance from akshat is 0.64285856
# Euclidean distance from siddhant is 1.0758477
# Euclidean distance from akshat is 0.7876588
# Euclidean distance from siddhant is 1.0176301
# Euclidean distance from akshat is 0.86772907
# Euclidean distance from siddhant is 0.9390278
# Euclidean distance from akshat is 0.94525486
# Euclidean distance from siddhant is 1.0812097
# Euclidean distance from akshat is 0.7755125
# Euclidean distance from siddhant is 0.9275074
# Euclidean distance from akshat is 0.9722695
# Euclidean distance from siddhant is 0.77756494
# Euclidean distance from akshat is 0.8942041
# Euclidean distance from siddhant is 0.9004532
# Euclidean distance from akshat is 0.63672686
# Euclidean distance from siddhant is 0.8953827
# Euclidean distance from akshat is 0.7379913
# Euclidean distance from siddhant is 0.8224113
# Euclidean distance from akshat is 0.6686568
# Euclidean distance from siddhant is 0.9102929
# Euclidean distance from akshat is 0.44962195
# Euclidean distance from siddhant is 1.0278585
# Euclidean distance from akshat is 0.43266988
# Euclidean distance from siddhant is 0.9739657
# Euclidean distance from akshat is 0.5249702
# Euclidean distance from siddhant is 1.0467302
# Euclidean distance from akshat is 0.581071
# Euclidean distance from siddhant is 1.0572059
# Euclidean distance from akshat is 0.6527876
# Euclidean distance from siddhant is 1.0990229
# Euclidean distance from akshat is 0.66245955
# Euclidean distance from siddhant is 1.1406031
# Euclidean distance from akshat is 0.69823
# Euclidean distance from siddhant is 1.1064339
# Euclidean distance from akshat is 0.68998367
# Euclidean distance from siddhant is 1.1538584
# Euclidean distance from akshat is 0.7268029
# Euclidean distance from siddhant is 1.1887791
# Euclidean distance from akshat is 0.8163299
# Euclidean distance from siddhant is 0.59917223
# Euclidean distance from akshat is 0.7592622
# Euclidean distance from siddhant is 1.1078136
# Euclidean distance from akshat is 0.6644256
# Euclidean distance from siddhant is 1.130106
# Euclidean distance from akshat is 0.7009578
# Euclidean distance from siddhant is 1.1868838
# Euclidean distance from akshat is 0.6681004
# Euclidean distance from siddhant is 1.1469114
# Euclidean distance from akshat is 0.69894725
# Euclidean distance from siddhant is 1.1379997
# Euclidean distance from akshat is 0.658909
# Euclidean distance from siddhant is 1.1246451
# Euclidean distance from akshat is 0.77110875
# Euclidean distance from siddhant is 1.0496058
# Euclidean distance from akshat is 0.5493415
# Euclidean distance from siddhant is 1.0713133
# Euclidean distance from akshat is 0.6633143
# Euclidean distance from siddhant is 1.1128728
# Euclidean distance from akshat is 0.6930164
# Euclidean distance from siddhant is 0.9901833
# Euclidean distance from akshat is 0.5453138
# Euclidean distance from siddhant is 1.1465625
# Euclidean distance from akshat is 0.48631185
# Euclidean distance from siddhant is 1.1246277
# Euclidean distance from akshat is 0.626119
# Euclidean distance from siddhant is 1.1300532
# Euclidean distance from akshat is 0.7808628
# Euclidean distance from siddhant is 0.7055287
# Euclidean distance from akshat is 0.79139686
# Euclidean distance from siddhant is 0.6529295
# Euclidean distance from akshat is 0.67422175
# Euclidean distance from siddhant is 0.6427505
# Euclidean distance from akshat is 0.8216544
# Euclidean distance from siddhant is 0.42568105
# Euclidean distance from akshat is 1.0940591
# Euclidean distance from siddhant is 0.6002381
# Euclidean distance from akshat is 0.7302471
# Euclidean distance from siddhant is 0.58673054
# Euclidean distance from akshat is 0.71901953
# Euclidean distance from siddhant is 0.6306499
# Euclidean distance from akshat is 0.6720119
# Euclidean distance from siddhant is 1.0649194
# Euclidean distance from akshat is 0.74739623
# Euclidean distance from siddhant is 0.62148345
# Euclidean distance from akshat is 0.69376683
# Euclidean distance from siddhant is 0.96003205
# Euclidean distance from akshat is 0.67069817
# Euclidean distance from siddhant is 1.0201381
# Euclidean distance from akshat is 0.64489853
# Euclidean distance from siddhant is 1.04298
# Euclidean distance from akshat is 0.69726354
# Euclidean distance from siddhant is 1.0547342
# Euclidean distance from akshat is 0.7258637
# Euclidean distance from siddhant is 1.1028819
# Euclidean distance from akshat is 0.6876702
# Euclidean distance from siddhant is 1.0825299
# Euclidean distance from akshat is 0.6715147
# Euclidean distance from siddhant is 1.0446204
# Euclidean distance from akshat is 0.58712685
# Euclidean distance from siddhant is 0.994288
# Euclidean distance from akshat is 0.6474454
# Euclidean distance from siddhant is 1.0423055
# Euclidean distance from akshat is 0.6376909
# Euclidean distance from siddhant is 1.0661135
# Euclidean distance from akshat is 0.68893224
# Euclidean distance from siddhant is 1.1063923
# Euclidean distance from akshat is 1.2729542
# Euclidean distance from siddhant is 0.93141866
# Euclidean distance from akshat is 0.74281454
# Euclidean distance from siddhant is 1.1240699
# Euclidean distance from akshat is 0.6985069
# Euclidean distance from siddhant is 1.0741475
# Euclidean distance from akshat is 0.6451615
# Euclidean distance from siddhant is 0.94859827
# Euclidean distance from akshat is 0.6914967
# Euclidean distance from siddhant is 1.081517
# Euclidean distance from akshat is 0.64129764
# Euclidean distance from siddhant is 1.0634744
# Euclidean distance from akshat is 0.6447291
# Euclidean distance from siddhant is 1.0192759
# Euclidean distance from akshat is 0.6862593
# Euclidean distance from siddhant is 0.9018753
# Euclidean distance from akshat is 0.7797096
# Euclidean distance from siddhant is 0.9099814
# Euclidean distance from akshat is 1.0390236
# Euclidean distance from siddhant is 0.75732785
# Euclidean distance from akshat is 0.7191401
# Euclidean distance from siddhant is 1.1287845
# Euclidean distance from akshat is 1.071637
# Euclidean distance from siddhant is 0.63722175
# Euclidean distance from akshat is 0.6507988
# Euclidean distance from siddhant is 0.81179553
# Euclidean distance from akshat is 0.8879624
# Euclidean distance from siddhant is 0.45418346
